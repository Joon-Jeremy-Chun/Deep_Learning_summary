# %% [markdown]
# # Kaggle 신용카드 사기 검출 (Google Drive Mount)
# https://www.kaggle.com/mlg-ulb/creditcardfraud
# ## Credit Card Fraud Detection
# * creditcard.csv (284,807 * 31)
# * Class : 0 (정상), 1 (사기)
# * 사기 검출(Fraud Detection), 이상 탐지(Anomaly Detection)

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # I. Google Drive Mount
# * 'creditCardFraud.zip' 파일을 구글드라이브에 업로드 후 진행

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# * 마운트 결과 확인

# %%
# !ls -l '/content/drive/My Drive/Colab Notebooks/datasets/creditCardFraud.zip'
# Out:
# -rw------- 1 root root 69155672 Mar  4 04:46 '/content/drive/My Drive/Colab Notebooks/datasets/creditCardFraud.zip'

# %% [markdown]
# # II. Data Preprocessing

# %% [markdown]
# > ## 1) Unzip 'creditCardFraud.zip'
#
# * Colab 파일시스템에 'creditcard.csv' 파일 생성

# %%
# !unzip /content/drive/My\ Drive/Colab\ Notebooks/datasets/creditCardFraud.zip
# Out:
# Archive:  /content/drive/My Drive/Colab Notebooks/datasets/creditCardFraud.zip
#   inflating: creditcard.csv

# %% [markdown]
# * creditcard.csv 파일 확인

# %%
# !ls -l
# Out:
# total 147304
# -rw-r--r-- 1 root root 150828752 Sep 20  2019 creditcard.csv
# drwx------ 5 root root      4096 Aug  5 01:05 drive
# drwxr-xr-x 1 root root      4096 Jul 16 13:20 sample_data

# %% [markdown]
# > ## 2) 데이터 읽어오기
#
# * pandas DataFrame

# %%
import pandas as pd

DF = pd.read_csv('creditcard.csv')

DF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
#  20  V20     284807 non-null  float64
#  21  V21     284807 non-null  float64
#  22  V22     284807 non-null  float64
#  23  V23     284807 non-null  float64
#  24  V24     284807 non-null  float64
#  25  V25     284807 non-null  float64
#  26  V26     284807 non-null  float64
#  27  V27     284807 non-null  float64
#  28  V28     284807 non-null  float64
#  29  Amount  284807 non-null  float64
#  30  Class   284807 non-null  int64
# dtypes: float64(30), int64(1)
# memory usage: 67.4 MB

# %%
DF.head()
# Out:
#    Time        V1        V2        V3  ...       V27       V28  Amount  Class
# 0   0.0 -1.359807 -0.072781  2.536347  ...  0.133558 -0.021053  149.62      0
# 1   0.0  1.191857  0.266151  0.166480  ... -0.008983  0.014724    2.69      0
# 2   1.0 -1.358354 -1.340163  1.773209  ... -0.055353 -0.059752  378.66      0
# 3   1.0 -0.966272 -0.185226  1.792993  ...  0.062723  0.061458  123.50      0
# 4   2.0 -1.158233  0.877737  1.548718  ...  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %% [markdown]
# * 0 (정상) Class와 1 (사기) Class 개수

# %%
DF.Class.value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %% [markdown]
# * 0 (정상) Class와 1 (사기) Class 비율

# %%
(DF.Class.value_counts() / DF.shape[0]) * 100
# Out:
# 0    99.827251
# 1     0.172749
# Name: Class, dtype: float64

# %% [markdown]
# > ## 3) Time 열(Column) 삭제

# %%
DF.drop('Time', axis = 1, inplace = True)

DF.head(1)
# Out:
#          V1        V2        V3        V4  ...       V27       V28  Amount  Class
# 0 -1.359807 -0.072781  2.536347  1.378155  ...  0.133558 -0.021053  149.62      0
#
# [1 rows x 30 columns]

# %% [markdown]
# > ## 4) train_test_split( )
#
# * X (Input), y (Output) 지정

# %%
X = DF.iloc[:,:-1]
y = DF.iloc[:, -1]

X.shape, y.shape
# Out:
# ((284807, 29), (284807,))

# %% [markdown]
# * With 'Stratify'

# %%
from sklearn.model_selection import train_test_split 

X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    test_size = 0.3,
                                                    random_state = 2045,
                                                    stratify = y)

X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((199364, 29), (199364,), (85443, 29), (85443,))

# %% [markdown]
# * Train_Data와 Test_Data의 1 (부정) 비율이 균형

# %%
print('Train_Data :','\n', (y_train.value_counts() / y_train.shape[0]) * 100)
print('Test_Data :','\n', (y_test.value_counts() / y_test.shape[0]) * 100)
# Out:
# Train_Data :
#  0    99.827451
# 1     0.172549
# Name: Class, dtype: float64
# Test_Data :
#  0    99.826785
# 1     0.173215
# Name: Class, dtype: float64

# %% [markdown]
# # I. Keras Modeling

# %% [markdown]
# > ## 1) Import Tensorflow

# %% [markdown]
# * Tensorflow Version 확인

# %%
import tensorflow

tensorflow.__version__
# Out:
# '2.5.0'

# %% [markdown]
# > ## 2) Model Define

# %% [markdown]
# * 모델 신경망 구조 정의

# %%
from tensorflow.keras import models
from tensorflow.keras import layers

ccfd = models.Sequential()
ccfd.add(layers.Dense(128, activation = 'relu', input_shape = (29,)))
ccfd.add(layers.Dense(64, activation = 'relu'))
ccfd.add(layers.Dense(32, activation = 'relu'))
ccfd.add(layers.Dense(1, activation = 'sigmoid'))

# %% [markdown]
# * 모델 구조 확인

# %%
ccfd.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 128)               3840
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_2 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 14,209
# Trainable params: 14,209
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# > ## 3) Model Compile

# %% [markdown]
# * 모델 학습방법 설정

# %%
ccfd.compile(loss = 'binary_crossentropy',
             optimizer = 'adam',
             metrics = ['Recall'])

# %% [markdown]
# > ## 4) Model Fit

# %% [markdown]
# * 모델 학습 수행

# %%
# %%time

Hist_ccfd = ccfd.fit(X_train, y_train,
                     epochs = 50,
                     batch_size = 1024,
                     validation_data = (X_test, y_test))
# Out:
# Epoch 1/50
# 195/195 [==============================] - 3s 7ms/step - loss: 0.0443 - recall: 0.4099 - val_loss: 0.0044 - val_recall: 0.8311
# Epoch 2/50
# 195/195 [==============================] - 1s 6ms/step - loss: 0.0247 - recall: 0.6395 - val_loss: 0.0320 - val_recall: 0.5676
# Epoch 3/50
# 195/195 [==============================] - 1s 6ms/step - loss: 0.0115 - recall: 0.6948 - val_loss: 0.0448 - val_recall: 0.4122
# Epoch 4/50
# 195/195 [==============================] - 1s 7ms/step - loss: 0.0234 - recall: 0.6686 - val_loss: 0.0036 - val_recall: 0.8311
# Epoch 5/50
# 195/195 [==============================] - 1s 6ms/step - loss: 0.0047 - recall: 0.7762 - val_loss: 0.0040 - val_recall: 0.8378
# Epoch 6/50
# 195/195 [==============================] - 1s 6ms/step - loss: 0.0048 - recall: 0.7791 - val_loss: 0.0036 - val_recall: 0.8514
# Epoch 7/50
# 195/195 [==============================] - 1s 6ms/step - loss: 0.0276 - recall: 0.6890 - val_loss: 0.0051 - val_recall: 0.8311
# Epoch 8/50
# 195/195 [==============================] - 1s 6ms/step - loss: 0.0071 - recall: 0.7645 - val_loss: 0.0042 - val_recall: 0.8243
# Epoch 9/50
# 195/195 [==============================] - 1s 7ms/step - loss: 0.0041 - recall: 0.7558 - val_loss: 0.0033 - val_recall: 0.8243
# Epoch 10/50
# 195/195 [==============================] - 1s 6ms/step - loss: 0.0044 - recall: 0.7733 - val_loss: 0.0031 - val_recall: 0.8446
# Epoch 11/50
# 195/195 [==============================] - 1s 6ms/step - loss: 0.0034 - recall: 0.8052 - val_loss: 0.0032 - val_recall: 0.8243
# Epoch 12/50
# 195/195 [==============================] - 1s 6ms/step - loss: 0.0031 - recall: 0.8023 - val_loss: 0.0029 - val_recall: 0.8446
# Epoch 13/50
# 195/195 [==============================] - 1s 7ms/step - loss: 0.0042 - recall: 0.7733 - val_loss: 0.0130 - val_recall: 0.5135
# Epoch 14/50
# 195/195 [==============================] - 1s 6ms/step - loss: 0.0062 - recall: 0.7820 - val_loss: 0.0027 - val_recall: 0.8378
# Epoch 15/50
# 195/195 [==============================] - 1s 7ms/step - loss: 0.0071 - recall: 0.7384 - val_loss: 0.0028 - val_recall: 0.8581
# Epoch 16/50
# 195/195 [==============================] - 1s 6ms/step - loss: 0.0028 - recall: 0.8081 - val_loss: 0.0024 - val_recall: 0.8378
# Epoch 17/50
# 195/195 [==============================] - 1s 6ms/step - loss: 0.0025 - recall: 0.8227 - val_loss: 0.0027 - val_recall: 0.8581
# Epoch 18/50
# 195/195 [==============================] - 1s 6ms/step - loss: 0.0032 - recall: 0.8081 - val_loss: 0.0042 - val_recall: 0.6622
# Epoch 19/50
# 195/195 [==============================] - 1s 6ms/step - loss: 0.0031 - recall: 0.8081 - val_loss: 0.0025 - val_recall: 0.8311
# Epoch 20/50
# 195/195 [==============================] - 1s 6ms/step - loss: 0.0042 - recall: 0.7994 - val_loss: 0.0032 - val_recall: 0.8581
# Epoch 21/50
# 195/195 [==============================] - 1s 7ms/step - loss: 0.0029 - recall: 0.8052 - val_loss: 0.0026 - val_recall: 0.8581
# Epoch 22/50
# 195/195 [==============================] - 1s 6ms/step - loss: 0.0028 - recall: 0.8081 - val_loss: 0.0025 - val_recall: 0.8108
# Epoch 23/50
# 195/195 [==============================] - 1s 7ms/step - loss: 0.0027 - recall: 0.8256 - val_loss: 0.0029 - val_recall: 0.8784
# Epoch 24/50
# 195/195 [==============================] - 1s 7ms/step - loss: 0.0041 - recall: 0.7965 - val_loss: 0.0029 - val_recall: 0.8581
# Epoch 25/50
# 195/195 [==============================] - 1s 6ms/step - loss: 0.0022 - recall: 0.8227 - val_loss: 0.0026 - val_recall: 0.8446
# Epoch 26/50
# 195/195 [==============================] - 1s 7ms/step - loss: 0.0023 - recall: 0.8285 - val_loss: 0.0025 - val_recall: 0.8784
# Epoch 27/50
# 195/195 [==============================] - 1s 6ms/step - loss: 0.0024 - recall: 0.8343 - val_loss: 0.0026 - val_recall: 0.8649
# Epoch 28/50
# 195/195 [==============================] - 1s 7ms/step - loss: 0.0022 - recall: 0.8140 - val_loss: 0.0032 - val_recall: 0.8649
# Epoch 29/50
# 195/195 [==============================] - 1s 6ms/step - loss: 0.0021 - recall: 0.8256 - val_loss: 0.0025 - val_recall: 0.8514
# Epoch 30/50
# 195/195 [==============================] - 1s 6ms/step - loss: 0.0024 - recall: 0.8343 - val_loss: 0.0027 - val_recall: 0.8176
# Epoch 31/50
# 195/195 [==============================] - 1s 7ms/step - loss: 0.0026 - recall: 0.8169 - val_loss: 0.0026 - val_recall: 0.7973
# Epoch 32/50
# 195/195 [==============================] - 1s 6ms/step - loss: 0.0022 - recall: 0.8285 - val_loss: 0.0029 - val_recall: 0.8716
# Epoch 33/50
# 195/195 [==============================] - 1s 7ms/step - loss: 0.0021 - recall: 0.8459 - val_loss: 0.0026 - val_recall: 0.8446
# Epoch 34/50
# 195/195 [==============================] - 1s 6ms/step - loss: 0.0021 - recall: 0.8372 - val_loss: 0.0027 - val_recall: 0.8311
# Epoch 35/50
# 195/195 [==============================] - 1s 6ms/step - loss: 0.0022 - recall: 0.8430 - val_loss: 0.0028 - val_recall: 0.8514
# Epoch 36/50
# 195/195 [==============================] - 1s 6ms/step - loss: 0.0020 - recall: 0.8459 - val_loss: 0.0029 - val_recall: 0.7500
# Epoch 37/50
# 195/195 [==============================] - 1s 7ms/step - loss: 0.0022 - recall: 0.8430 - val_loss: 0.0030 - val_recall: 0.8108
# Epoch 38/50
# 195/195 [==============================] - 1s 7ms/step - loss: 0.0019 - recall: 0.8488 - val_loss: 0.0031 - val_recall: 0.8649
# Epoch 39/50
# 195/195 [==============================] - 1s 6ms/step - loss: 0.0018 - recall: 0.8517 - val_loss: 0.0030 - val_recall: 0.8581
# Epoch 40/50
# 195/195 [==============================] - 1s 6ms/step - loss: 0.0017 - recall: 0.8547 - val_loss: 0.0035 - val_recall: 0.8446
# Epoch 41/50
# 195/195 [==============================] - 1s 7ms/step - loss: 0.0021 - recall: 0.8547 - val_loss: 0.0031 - val_recall: 0.8649
# Epoch 42/50
# 195/195 [==============================] - 1s 6ms/step - loss: 0.0022 - recall: 0.8459 - val_loss: 0.0030 - val_recall: 0.8378
# Epoch 43/50
# 195/195 [==============================] - 1s 6ms/step - loss: 0.0019 - recall: 0.8343 - val_loss: 0.0033 - val_recall: 0.8108
# Epoch 44/50
# 195/195 [==============================] - 1s 7ms/step - loss: 0.0049 - recall: 0.7936 - val_loss: 0.0034 - val_recall: 0.8716
# Epoch 45/50
# 195/195 [==============================] - 1s 6ms/step - loss: 0.0032 - recall: 0.8459 - val_loss: 0.0031 - val_recall: 0.8446
# Epoch 46/50
# 195/195 [==============================] - 1s 6ms/step - loss: 0.0030 - recall: 0.8372 - val_loss: 0.0039 - val_recall: 0.8243
# Epoch 47/50
# 195/195 [==============================] - 1s 5ms/step - loss: 0.0018 - recall: 0.8576 - val_loss: 0.0039 - val_recall: 0.8514
# Epoch 48/50
# 195/195 [==============================] - 1s 6ms/step - loss: 0.0017 - recall: 0.8605 - val_loss: 0.0033 - val_recall: 0.8649
# Epoch 49/50
# 195/195 [==============================] - 1s 7ms/step - loss: 0.0019 - recall: 0.8430 - val_loss: 0.0034 - val_recall: 0.8716
# Epoch 50/50
# 195/195 [==============================] - 1s 6ms/step - loss: 0.0017 - recall: 0.8517 - val_loss: 0.0035 - val_recall: 0.8784
# CPU times: user 1min 19s, sys: 5.22 s, total: 1min 24s
# Wall time: 1min 1s

# %% [markdown]
# > ## 5) 학습 결과 시각화

# %% [markdown]
# * Loss Visualization

# %%
import matplotlib.pyplot as plt

epochs = range(1, len(Hist_ccfd.history['loss']) + 1)

plt.figure(figsize = (9, 6))
plt.plot(epochs, Hist_ccfd.history['loss'])
plt.plot(epochs, Hist_ccfd.history['val_loss'])
plt.title('Training & Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(['Training Loss', 'Validation Loss'])
plt.grid()
plt.show()

# %% [markdown]
# * Recall Visualization

# %%
import matplotlib.pyplot as plt

epochs = range(1, len(Hist_ccfd.history['recall']) + 1)

plt.figure(figsize = (9, 6))
plt.plot(epochs, Hist_ccfd.history['recall'])
plt.plot(epochs, Hist_ccfd.history['val_recall'])
plt.title('Training & Validation Recall')
plt.xlabel('Epochs')
plt.ylabel('Recall')
plt.legend(['Training Recall', 'Validation Recall'])
plt.grid()
plt.show()

# %% [markdown]
# > ## 6) Model Evaluate

# %% [markdown]
# * Loss & Accuracy

# %%
loss, recall = ccfd.evaluate(X_test, y_test)

print('Loss = {:.5f}'.format(loss))
print('Recall = {:.5f}'.format(recall))
# Out:
# 2671/2671 [==============================] - 3s 1ms/step - loss: 0.0035 - recall: 0.8784
# Loss = 0.00354
# Recall = 0.87838

# %% [markdown]
# > ## 7) Model Predict

# %%
y_hat = ccfd.predict_classes(X_test)

# %%
from sklearn.metrics import confusion_matrix

confusion_matrix(y_test, y_hat)
# Out:
# array([[85278,    17],
#        [   18,   130]])

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score

print(accuracy_score(y_test, y_hat))
print(precision_score(y_test, y_hat, pos_label = 1))
print(recall_score(y_test, y_hat, pos_label = 1))
# Out:
# 0.9995903701883126
# 0.8843537414965986
# 0.8783783783783784

# %% [markdown]
# #
# #
# #
# # The End
# #
# #
# #
